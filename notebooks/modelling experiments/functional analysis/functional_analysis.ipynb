# %%
import nest
import numpy as np
import matplotlib.pyplot as plt
import pickle
from scripts import correlation_analysis
# Out:
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.6.0
#  Built: Sep 28 2023 11:53:34
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.

# %%
categorised_neurons_path = '/hpc/mzhu843/modelling/nest/DATA/processed/model1/categorised_neurons_5.pkl'
spike_trains_path = '/hpc/mzhu843/modelling/nest/DATA/processed/spikes/S_5_p.npy'

# %%
with open(categorised_neurons_path, 'rb') as file:
    categorised_neurons = pickle.load(file)
spike_trains = np.load(spike_trains_path)

# %%
place_cell_ids = categorised_neurons['Place'].keys()
interneuron_ids = categorised_neurons['Interneuron'].keys()

# %%
functional = correlation_analysis.CorrelationAnalysis(spike_trains, place_cell_ids, interneuron_ids)
functional.compute_correlation_matrix()

functional.plot_correlation_matrix()
plt.savefig('/hpc/mzhu843/modelling/nest/plots/experiments/functional analysis/correlation matrix.png')

# %%
functional.print_stats()
# Out:
# Place to place mean:  0.00156671173133721
# Place to place std:  0.011032009150218826
# Place to interneuron mean:  0.00029230391468053693
# Place to interneuron std:  0.008171518481513951
# Interneuron to place mean:  0.0002923039146805368
# Interneuron to place std:  0.008171518481513953
# Interneuron to interneuron mean:  0.000843275716290648
# Interneuron to neuron std:  0.009427139641322375
# Full mean:  0.0009126829079042023
# Full std:  0.00967989353559374
