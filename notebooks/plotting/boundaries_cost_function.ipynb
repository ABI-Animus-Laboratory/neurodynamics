# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def func(x):
    return (np.abs((x + 60) ** 2) * 0.01) * 0.9 + 0.1
x = np.linspace(-71, -49, 500)
y = func(x)

fig = plt.figure(figsize=(5,6))
plt.plot(x,y)
plt.xlabel('Voltage (mV)')
plt.ylabel('Weight')
# Out:
# Text(0, 0.5, 'Weight')
