# %%
import numpy as np
import nest
import matplotlib.pyplot as plt

from scripts import visualizations, initializations, optimization, experiments
# Out:
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.6.0
#  Built: Sep 28 2023 11:53:34
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.

# %%
nest.rng_seed = 1
np.random.seed(1)

# %%
optimized_weights = np.load('/hpc/mzhu843/modelling/nest/DATA/matrices/optimised_matrix.npy')

# %%
results, spike_recorder = experiments.run_s1(optimized_weights)
# Out:
# Dec 13 13:39:53 correlation_detector [Info]:
#     Default for delta_tau changed from 0.5 to 5 ms
#
# Dec 13 13:39:53 correlomatrix_detector [Info]:
#     Default for delta_tau changed from 0.5 to 5 ms
#
# Dec 13 13:39:53 correlospinmatrix_detector [Info]:
#     Default for delta_tau changed from 0.1 to 1 ms
#
# Dec 13 13:39:53 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 1 ms.
#
# Dec 13 13:39:53 NodeManager::prepare_nodes [Info]:
#     Preparing 280 nodes for simulation.
#
# Dec 13 13:39:53 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 280
#     Simulation time (ms): 17988
#     Number of OpenMP threads: 1
#     Not using MPI
#
# Dec 13 13:39:53 SimulationManager::run [Info]:
#     Simulation finished.

# %%
nest.raster_plot.from_device(spike_recorder)
